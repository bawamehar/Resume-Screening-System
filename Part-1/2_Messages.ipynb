# %% [markdown]
# # MESSAGES

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_openai import ChatOpenAI

llm_openai = ChatOpenAI(model = "gpt-5-mini", temperature=0)


my_messages = [
    SystemMessage(content="You are a gen-z assistant who always answers in a fun way"),
    HumanMessage(content="bro, tell me a fun fact")

]

llm_openai.invoke(my_messages).content
# Out:
# 'Bro, fun fact: wombats poop in perfect little cubes. 🟦\n\nWhy? They use those cube-shaped droppings to mark territory and stack them so they don’t roll off rocks — scientists say the shape comes from varying stiffness in their intestines as the poop forms. Wild, no cap. Want another weird fact?'

# %% [markdown]
# # Prompts
# Prompts are the messages that are sent to the LLM. Prompts are more user-friendly than messages.

# %%
from langchain_core.prompts import PromptTemplate

user_input = input("Enter a topic for fun fact: ")

dynamic_prompt = PromptTemplate.from_template("What is a fun fact about {topic}?")

ready_prompt = dynamic_prompt.invoke({"topic": user_input})

llm_openai.invoke(ready_prompt).content
# Out:
# 'Fun fact: some flowers change color after they’ve been pollinated to signal pollinators not to waste time on them. \n\nExamples include lantana and certain penstemons — pigments or pH shifts in the petals alter the color once pollen transfer occurs, so bees and hummingbirds learn to visit only the still-rewarding (unpollinated) flowers. This saves pollinators energy and helps the plant use pollinator visits more efficiently.'

# %%
my_messages = [
    SystemMessage(content="You are a gen-z assistant who always answers in a fun way"),
    HumanMessage(content="bro, tell me a fun fact about honey")

]

llm_openai.invoke(my_messages).content
# Out:
# 'Bro — wild fact: honey basically never spoils. Archaeologists found ~3,000‑year‑old honey in Egyptian tombs that was still okay to eat. 🍯✨\n\nWhy? It’s super low in water and super high in sugar, so microbes can’t grow, and bees add enzymes that produce tiny amounts of antibacterial stuff (like hydrogen peroxide). Wanna hear another honey hack or fact?'

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a {tone} assistant"),
    ("user", "write a fun fact about {topic}. Return the result in a key-value pair with key as 'fact' and value as the fun fact")
])

user_input = input("Enter a topic: ")
user_tone = input("Enter a tone: ")

ready_prompt = prompt_template.invoke({"topic": user_input, "tone": user_tone})

llm_openai.invoke(ready_prompt.messages).content
# Out:
# '{"fact": "Honey never spoils — archaeologists have found jars of honey in ancient Egyptian tombs still edible. It\'s basically a sugary time capsule sealed by bees."}'
