# %% [markdown]
# # LLM CALL

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm_openai = ChatOpenAI(model = "gpt-5-mini", temperature=0)

llm_openai.invoke("bro, tell me a fun fact").content
# Out:
# 'Bro — fun fact: bananas are botanically berries, but strawberries aren’t. Botanically a “berry” comes from one flower with one ovary (so bananas, tomatoes, and even kiwifruit count), while strawberries are aggregate fruits made from many tiny ovaries. Want another one?'

# %%
from langchain.chat_models import init_chat_model

llm_openai = init_chat_model(model = "gpt-5-mini", temperature=0)

llm_openai.invoke("Hello, how are you?")
# Out:
# AIMessage(content="Hi — I'm doing well, thanks! How can I help you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 12, 'total_tokens': 36, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DCUqsSCpnjK2pPRAEGZjnIwQq0VIM', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c8bbc-58b4-7af0-a3f2-f014101b9dac-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 24, 'total_tokens': 36, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
